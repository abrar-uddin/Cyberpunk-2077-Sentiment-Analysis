# %%
import sqlite3
import pandas as pd
from wordcloud import WordCloud

# %%
db_conn = sqlite3.connect("Cyberpunk2077 YT Comments.db")
c = db_conn.cursor()

input_file = "comments.csv"
# read_comments = pd.read_csv(input_file, lineterminator='\n')
# read_comments.to_sql("COMMENTS", db_conn, if_exists='append', index=False)
# df = pd.read_sql_query('SELECT text, author, likeCount FROM COMMENTS LIMIT 10', db_conn)

# %%
raw_comments = pd.read_csv(input_file, lineterminator='\n')

# %%
from IPython.display import display

with pd.option_context('display.max_rows', 100, 'display.max_columns', 100):
    display(raw_comments['text'].head(20))
# Out:
# 0     This game are mix with the 80s and the future....
# 1       29:02 "Remember, these guys are really *shit* "
# 2                      I would replay this game 100x 💯‼
# 3     So you could complete the game without killing...
# 4     After listening to this video, I'm wondering i...
# 5     Next level by CDPR, they even got Triss Merigo...
# 6                                      Nothing special.
# 7                     you can never go wrong with rocky
# 8     It´s going to be one the best games of our cen...
# 9           Why tf they r not releasing it in lockdown?
# 10                 This game was supposed to be out rn😔
# 11                                2:00 for those people
# 12                               Time to be Deathstroke
# 13         I wish there were many weapons of each type!
# 14    Been watching this video over and over, still ...
# 15    Been watching this video over and over, still ...
# 16               Who needs this shit. I just need GTA 6
# 17                    Please, September, come soon! 🤘🏻🤩
# 18            🤘🏻\n*PLEASE SUBSCRIBE IN MY CHANNEL* 🙏🏻❤️
# 19    It sounds sooo much bollywood.\n1:09 diwani ma...
# Name: text, dtype: object

# %%
data = raw_comments.drop(['videoId', 'commentId', 'publishedAt'], axis=1)

# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import re, string, unicodedata
import nltk
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.corpus import stopwords, wordnet
from nltk.stem import LancasterStemmer, WordNetLemmatizer
from nltk.tokenize import TweetTokenizer
import preprocessor as p

class TextCleaner:
    '''
    
    '''
    
    def __init__(self):
        pass
        
    
    '''
    
    Parameters
    ----------
        
    list_of_text :
    
    Returns
    -------
    
    list
    '''    
    def clean(self, list_of_text):
        cleaned_text = []
        for x in list_of_text:
            text = self.lower_case(x)
            text = self.general_clean(text)
            text = self.remove_digits(text)
            text = self.remove_punctuation(text)
            text = self.tokenize_and_lemmatize(text)            
            cleaned_text.append(text)
            
        cleaned_text = self.remove_stop_words(cleaned_text)
        
        return cleaned_text
    
    '''
    Used to lower case the passed text.
    
    Parameters
    ----------
        
    text :
    
    Returns
    -------
    
    str
        text lower cased
    '''    
    def lower_case(self, text):
        return str(text.lower())
    
    ''' 
    From the tweet-preprocessor package using preprocessor to remove 
    URLs, Hashtags, Mentions, Reserved words (RT, FAV), Emojis, Smileys.
    
    Parameters
    ----------
        
    text :
    
    Returns
    -------
    
    str
        text with URLs, Hashtags, Mentions, Reserved words (RT, FAV), 
        Emojis, Smileys removed.
    '''
    def general_clean(self, text):
        return p.clean(text)
    
    '''
    Used to remove any numbers from the text.
    
    Parameters
    ----------
        
    text :
    
    Returns
    -------
    
    str
        text with digits removed.
    '''
    def remove_digits(self, text):
        return re.sub(r'\d+', '', text)
    
    '''
    Used to remove any punctuation from the text.
    
    Parameters
    ----------
        
    text :
    
    Returns
    -------
    
    str
        text with punctuations removed.
    '''
    def remove_punctuation(self, text):
        return re.sub(r'[^\w\s]', '', text)
    
    '''
    Used to tokenize and lemmatize the passed text.
    
    Parameters
    ----------
        
    text :
    
    Returns
    -------
    
    list
        a list of tokenized words extracted from the text
    '''
    def tokenize_and_lemmatize(self, text):
        lemmatizer = nltk.stem.WordNetLemmatizer()
        tokenizer = TweetTokenizer()
        return [(lemmatizer.lemmatize(w)) for w in tokenizer.tokenize((text))]
    
    '''
    Used to remove stop words.
    
    Parameters
    ----------
        
    text : list
        tokenized version of the text
        
    Returns
    -------
    
    pandas.Dataframe
        a list of tokenized words with stop words removed
    '''
    def remove_stop_words(self, text):
        stop_words = set(stopwords.words('english'))
        text = pd.Series(text)
        text = text.apply(lambda x: [item for item in x if item not in stop_words])
        return text

# %%
cleaner = TextCleaner()
cleaned_comments = cleaner.clean(data['text'].astype(str))

# %%
cleaned_data = data.copy()
cleaned_data['cleaned_comments'] = cleaned_comments

# %%
cleaned_data.head(10)
# Out:
#                                                 text            author  \
# 0  This game are mix with the 80s and the future....  Brandon Brünious
# 1    29:02 "Remember, these guys are really *shit* "     The Mannequin
# 2                   I would replay this game 100x 💯‼     RazeSwag Swag
# 3  So you could complete the game without killing...     RazeSwag Swag
# 4  After listening to this video, I'm wondering i...     Chris Shannon
# 5  Next level by CDPR, they even got Triss Merigo...       Crazozourus
# 6                                   Nothing special.       Lud Buhalov
# 7                  you can never go wrong with rocky   Lorenzo Sanchez
# 8  It´s going to be one the best games of our cen...         Andi Batz
# 9        Why tf they r not releasing it in lockdown?     Yuvraj Sharma
#
#    likeCount                                   cleaned_comments
# 0          0              [game, mix, future, uwu, thats, neat]
# 1          0                      [remember, guy, really, shit]
# 2          1                           [would, replay, game, x]
# 3          1  [could, complete, game, without, killing, anyone]
# 4          0  [listening, video, im, wondering, mod, music, ...
# 5          0  [next, level, cdpr, even, got, triss, merigold...
# 6          0                                 [nothing, special]
# 7          0                          [never, go, wrong, rocky]
# 8          0                  [going, one, best, game, century]
# 9          0                       [tf, r, releasing, lockdown]

# %%
# cleaned_data.to_csv('cleaned_comments.csv')

# %%
for x in cleaned_data['cleaned_comments']:
    words += " ".join(x)

wordcloud = WordCloud().generate(words)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
